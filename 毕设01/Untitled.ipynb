# %% [markdown]
# # 整理形成语料库

# %% [markdown]
#  读取文件夹

# %%
# encoding: utf-8
'''
1、读取指定目录下的所有文件
2、读取文件，正则匹配出需要的内容，获取文件名
3、打开此文件(可以选择打开可以选择复制到别的地方去)
'''
import os.path
import re
 
 
# 遍历指定目录，显示目录下的所有文件名
def eachFile(filepath):
    pathDir =  os.listdir(filepath)
    
    for allDir in pathDir:
        child = os.path.join('%s\%s' % (filepath, allDir))
        if os.path.isfile(child):
            readFile(child)
            child.decode('utf-8')

            continue
        eachFile(child)
   
# 遍历出结果 返回文件的名字
def readFile(filenames):
        fopen = open(filenames, 'r',encoding='utf-8') # r 代表read
        fileread = fopen.read()
        fopen.close()
        t=re.search(r'信息加密技术在计算机网络安全中的应用_韩兵.pdf',fileread)
        if t:
#             print "匹配到的文件是:"+filenames
            arr.append(filenames)       
 
if __name__ == "__main__":
    filenames = 'C:/TMdata/pdf' # refer root dir
    arr=[]
    eachFile(filenames)
    for i in arr:
        print(i)

# %%
import pandas as pd
txt0 = pd.read_csv('C:/TMdata/txt/2.txt',names=['txt'],encoding="utf-8",sep='aaa',engine='python')
print(type(txt0.txt[0]))
n=0
txtlist = []
while n <= 30:
    txtlist.append(txt0.txt[0])
    n+=1
print(txtlist[1])

# %%
os.listdir('C:/TMdata/pdf')

# %%
all_list = os.listdir('C:\\Users\\Administrator\\Desktop\\资料\\师傅带徒弟学：Python图形用户界面编程wxPython视频课程')

for onelist in all_list:
    if onelist.find('.pdf') == -1:
        all_list.remove(onelist)
    
print(all_list)

# %%
all_list = os.listdir('C:/TMdata/pdf')
txt_list=[]
for onelist in all_list:
    if onelist.find('pdf') != -1:
        txt_list.append(onelist)
    
print(txt_list)

# %%
import sys
import importlib
importlib.reload(sys)

from pdfminer.pdfparser import PDFParser,PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import PDFPageAggregator
from pdfminer.layout import LTTextBoxHorizontal,LAParams
from pdfminer.pdfinterp import PDFTextExtractionNotAllowed
import os

def parse(txt_name,file_path):
    path = file_path+"/"+txt_name+".pdf"
    fp = open(path, 'rb')
# 以二进制读模式打开
#用文件对象来创建一个pdf文档分析器
    praser = PDFParser(fp)
# 创建一个PDF文档
    doc = PDFDocument()
# 连接分析器 与文档对象
    praser.set_document(doc)
    doc.set_parser(praser)

# 提供初始化密码
# 如果没有密码 就创建一个空的字符串
    doc.initialize()

# 检测文档是否提供txt转换，不提供就忽略
    if not doc.is_extractable:
        raise PDFTextExtractionNotAllowed
    else:
# 创建PDf 资源管理器 来管理共享资源
        rsrcmgr = PDFResourceManager()
# 创建一个PDF设备对象
        laparams = LAParams()
        device = PDFPageAggregator(rsrcmgr, laparams=laparams)
# 创建一个PDF解释器对象
        interpreter = PDFPageInterpreter(rsrcmgr, device)

# 循环遍历列表，每次处理一个page的内容
        for page in doc.get_pages(): # doc.get_pages() 获取page列表
            interpreter.process_page(page)
# 接受该页面的LTPage对象
            layout = device.get_result()
# 这里layout是一个LTPage对象 里面存放着 这个page解析出的各种对象 一般包括LTTextBox, LTFigure, LTImage, LTTextBoxHorizontal 等等 想要获取文本就获得对象的text属性，
        for x in layout:
            if (isinstance(x, LTTextBoxHorizontal)):
#需要写出编码格式
                with open(file_path +"/"+ txt_name +".txt", 'a',encoding='utf-8') as f:
                    results = x.get_text()
                    print(results)
                    f.write(results + '\n')
                    

if __name__ == '__main__':
    all_list = os.listdir('C:/TMdata/pdf')
    path = 'C:/TMdata/pdf'
    txt_list=[]
    for onelist in all_list:
        if onelist.find('pdf') != -1:
            txt_list.append(onelist[0:-4])
            
    print(txt_list)
    for i in range(len(txt_list)):
        parse(txt_list[i],path)
# Out:
# ['云计算辅助计算机操作系统教学路径研究_姜姗', '大数据环境下市场营销专业建设探讨_卢敏', '操作系统安全加固技术研究_莫怀海']
# 论述
#
# 212
#
# 2019 年 3 月
#
# 基于机器学习及电商数据预测用户行为
#
# 周志远（济宁孔子国际学校，山东省 济宁市 272000）
#
# 【摘 要】随着计算机及互联网的快速发展，电子商务渐渐成为国家经济的重要组成部分，如何从大数据中准确预测用户购物行为并进行个性
# 化推荐成为电商领域的研究热点。本文基于机器学习对英国电子商务数据进行基本分析，以文本处理及聚类的方式构造用户
# 产品矩阵及产品
# 和用户聚类，并实现支持向量机分类器对新用户进行分类，从而预测新用户的购买行为及模式。
# 【关键词】电子商务；文本处理；用户聚类；支持向量机；分类器
# 【文献标识码】A
#
# 【文章编号】1006-4222
#
# 【中图分类号】TP309
#
# 2019
#
# 03-0212-02
#
# （
#
# ）
#
# -
#
# 前 言
#
# 1
#
# 近年来， 随着计算机互联网技术尤其是移动互联网的发展 ，
# 网上购物的 “爆炸式 ”增长 ，带 动电子商务 行 业 的 突 飞 猛 进 [10]，
# 不 断地颠覆着人 们 的 生 活 习 惯 。 据 公 开 数 据 显 示 ，2018 年 天
# 猫双 11 全天成交额为 2135 亿人民币 ，此数据表明 ，网上购物
# 已经成为人们日常生活中购物的主要方式之一 。
# 电子商务是指基于计算机网络技术 ， 以购买物品为中心
# 的商业行为 [9]，是传统商业的行 为的电子化及信息化 。 在电子
# 商务日益发展的今天 ， 由网上交易而产生的数据已经成 为企
# 业的资产之一 ，如何更好地探究客户的购物行为 ，并促进产业
# 的发展已经成为相关企业的投资重点 。
# 即使如此 ，由于电商数据量之大维度之多 ，使得相关企业
# 从电商交易数据中获得有用 价值方面仍面临诸多难题 ， 尤其
# 是如何精准地分析及预测用户的行为 ， 并根据相关行 为进行
# 用户的分类以进行个性化营销及商品推荐 。
# 针对以上电商面临的难题 ， 本文结合对电子商务的数据
# 可视化分析及以支持向量机 进行用户购买行为的预测 ， 以综
# ...

# %%
import sys
import importlib
importlib.reload(sys)

from pdfminer.pdfparser import PDFParser, PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import PDFPageAggregator
from pdfminer.layout import LTTextBoxHorizontal, LAParams
from pdfminer.pdfinterp import PDFTextExtractionNotAllowed

def readPDF(path, toPath):
    # 以二进制形式打开pdf文件
    with open(path, "rb") as f:
        # 创建一个pdf文档分析器
        parser = PDFParser(f)
        # 创建pdf文档
        pdfFile = PDFDocument()
        # 链接分析器与文档对象
        parser.set_document(pdfFile)
        pdfFile.set_parser(parser)
        # 提供初始化密码
        pdfFile.initialize()
        # 检测文档是否提供txt转换
    if not pdfFile.is_extractable:
        raise PDFTextExtractionNotAllowed
    else:
        # 解析数据
        # 数据管理
        manager = PDFResourceManager()
        # 创建一个PDF设备对象
        laparams = LAParams()
        device = PDFPageAggregator(manager, laparams=laparams)
        # 解释器对象
        interpreter = PDFPageInterpreter(manager, device)

        # 开始循环处理，每次处理一页
        for page in pdfFile.get_pages():
            interpreter.process_page(page)
            layout = device.get_result()
            for x in layout:
                if(isinstance(x, LTTextBoxHorizontal)):
                    with open(toPath, "a") as f:
                        str = x.get_text()
                        # print(str)
                        f.write(str+"\n")

path = r"C:\TMdata\pdf\大数据环境下市场营销专业建设探讨_卢敏.pdf"
toPath = r"C:\TMdata\pdf\a.txt"
readPDF(path, toPath)

# %%
# -*- coding: utf-8 -*-
"""
Created on Tue Apr 23 16:17:30 2019

@author: Administrator
"""
import sys
import importlib
importlib.reload(sys)

from pdfminer.pdfparser import PDFParser, PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import PDFPageAggregator
from pdfminer.layout import LTTextBoxHorizontal, LAParams
from pdfminer.pdfinterp import PDFTextExtractionNotAllowed
import os

class WgShow():
    
    #从已知文件路径中读取pdf文件，并将其转化为同名txt文件
    
    
    def readPDF(path, toPath):
        # 以二进制形式打开pdf文件
        with open(path, "rb") as f:
            # 创建一个pdf文档分析器
            parser = PDFParser(f)
            # 创建pdf文档
            pdfFile = PDFDocument()
            # 链接分析器与文档对象
            parser.set_document(pdfFile)
            pdfFile.set_parser(parser)
            # 提供初始化密码
            pdfFile.initialize()
            # 检测文档是否提供txt转换
        if not pdfFile.is_extractable:
            raise PDFTextExtractionNotAllowed
        else:
            # 解析数据
            # 数据管理
            manager = PDFResourceManager()
            # 创建一个PDF设备对象
            laparams = LAParams()
            device = PDFPageAggregator(manager, laparams=laparams)
            # 解释器对象
            interpreter = PDFPageInterpreter(manager, device)
            
    
            # 开始循环处理，每次处理一页
            for page in pdfFile.get_pages():
                interpreter.process_page(page)
                layout = device.get_result()
                for x in layout:
                    if(isinstance(x, LTTextBoxHorizontal)):
                        with open(toPath, 'a',encoding='utf-8') as f:
                            str = x.get_text()
                            # print(str)
                            f.write(str+'\n')


    def getpdf_list(pdf_path):
        txt_path =  'C:/EdmsData/txt/'
        
        shanchu = os.listdir(txt_path)
        print(shanchu)
        for i in range(len(shanchu)):
            os.remove(txt_path+shanchu[i])
        
        all_list = os.listdir(pdf_path)
        path = 'C:/TMdata/pdf'
        
        txt_list=[]
        for onelist in all_list:
            if onelist.find('pdf') != -1:
                txt_list.append(onelist[0:-4])
                
        print(txt_list)
        for i in range(len(txt_list)):
            path = pdf_path+'/'+txt_list[i]+'.pdf'
            toPath = txt_path+txt_list[i]+'.txt'
            
            WgShow.readPDF(path,toPath)
            
            
if __name__ == '__main__':
    pdf_path = 'C:/TMdata/pdf'
    WgShow.getpdf_list(pdf_path)
# Out:
# ['云计算辅助计算机操作系统教学路径研究_姜姗.txt', '大数据环境下市场营销专业建设探讨_卢敏.txt', '操作系统安全加固技术研究_莫怀海.txt']
# ['云计算辅助计算机操作系统教学路径研究_姜姗', '大数据环境下市场营销专业建设探讨_卢敏', '操作系统安全加固技术研究_莫怀海']

# %%
class A():
    def b():
        print('b')
    def c():
        print('c')
        
if __name__ == '__main__':
   
    A.b()
    A.c()
# Out:
# b
# c
