# %%
#1.导包--官网
import sys
import importlib
importlib.reload(sys)

from pdfminer.pdfparser import PDFParser, PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import PDFPageAggregator
from pdfminer.layout import LTTextBoxHorizontal, LAParams
from pdfminer.pdfinterp import PDFTextExtractionNotAllowed
#2.获取文档对象
fp = open(r'C:\Users\Administrator\Desktop\毕设新\基于Web的数据挖掘技术研究与应用.pdf' ,'rb') #二进制模式读方式打开

#3.创建一个与文档关联的解释器
parser = PDFParser(fp)

#4.创建一个pdf文档对象
doc = PDFDocument()
#5.将两个对象连接起来--解释器与文档对象
parser.set_document(doc)
doc.set_parser(parser)

#6.初始化文档
doc.initialize("") #无密码

#7.创建一个资源管理器
resource = PDFResourceManager()

#8.创建一个参数分析器
laparam = LAParams()

#9.创建一个聚合器,接收一个资源管理器和一个参数分析器
device = PDFPageAggregator(resource,laparams = laparam)
#10.创建一个页面解释器，接收一个资源管理器和一个聚合器
interpreter = PDFPageInterpreter(resource,device)

#11.使用文档对象从页面中读取内容，得到页面的集合
for page in doc.get_pages():
    #使用页面解释器来读取
    interpreter.process_page(page)#将所有内容读取页面解释器
    
    #使用聚合器获取内容（页面解释器中是包含一个聚合器的，是将内容传到聚合器中）
    layout = device.get_result()

    for out in layout:
        if (isinstance(out, LTTextBoxHorizontal)):
            print(out.get_text())
# Out:
# WARNING:pdfminer.layout:Too many boxes (145) to group, skipping.
# 电脑编程技巧与维护
#
# 1 引言
#
# Web
#
# 上的信息量随着互联网的飞速发展以惊人的速度巨
# 增，在这些海量
# 分布
# 动态
# 异质
# 非结构化的资源中，
# 包含了丰富的文本
# 图形图像
# 声音等信息，同时也包含了
# 大量的链接结构信息以及存在于服务器上的用户记录信息
# 面对这些巨量的信息，管理者如何从中查找
# 抽取所需要的
# 数据与有用信息成了一个难题，也正是这个问题促使了单文
# 本
# 单类型的数据挖掘转向了
# 挖掘
# 本文基于这种背景
# 研究分析了
# 数据挖掘的定义
# 分类以及其挖掘技术，并
# 对其挖掘过程中存在的困难与引用进行简单了分析说明
#
# 、
#
# 、
#
# 、
#
# 、
#
# 、
#
# 、
#
# 。
#
# 、
#
# 、
#
# Web
#
# 。
#
# Web
#
# 、
#
# 。
#
# 2 定义与分类
#
# 2.1 概述
#
# 数据挖掘是指从大量的
# 不完全的
# 随机的
# 有噪音的
# 实际应用数据中发现隐含的
# 规律性的
# 人们事先未知的但
# 又是存在潜在价值知识的过程
# 数据挖掘是从数据挖掘
# 发展而来，一般是指将数据挖掘技术应用到
# 上
# 具体技
# 术性定义：
# 数据挖掘，简称为
# 挖掘，是一项涉及
# 数据挖掘
# 信息学
# 计算机语言学等多个领域的综合技
# 术
# 挖掘的理论性定义：指从大量
# 文档结构和使用
# 的集合
# 中发现隐含的
# 未知的
# 有潜在应用价值的模式
# 如果将
# 看作输入，
# 看作输出，那么
# 挖掘的过程就是
# 从输入到输出的一个映射
# 挖掘就是从
# 文档
# 活动中抽取出用户感兴
# 趣的
# 潜在有价值模型的隐藏信息
# 挖掘可以在很多方
# 面发挥作用，如对搜索引擎的结构进行挖掘
# 确定权威页面
# 文档分类
# 日志挖掘
# 智能查询
# 建立
# 元数据
# 对远程教育过程信息进行分析等
#
# 、
#
# 、
#
# 、
# ...

# %%
import sys
import importlib
importlib.reload(sys)

from pdfminer.pdfparser import PDFParser, PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import PDFPageAggregator
from pdfminer.layout import LTTextBoxHorizontal, LAParams
from pdfminer.pdfinterp import PDFTextExtractionNotAllowed

path = r'C:\Users\Administrator\Desktop\毕设新\基于Web的数据挖掘技术研究与应用.pdf'

# 用文件对象来创建一个pdf文档分析器
praser = PDFParser(open(path, 'rb'))
# 创建一个PDF文档
doc = PDFDocument()
# 连接分析器 与文档对象
praser.set_document(doc)
doc.set_parser(praser)

# 提供初始化密码
# 如果没有密码 就创建一个空的字符串
doc.initialize()

# 检测文档是否提供txt转换，不提供就忽略
if not doc.is_extractable:
    raise PDFTextExtractionNotAllowed
else:
    # 创建PDf 资源管理器 来管理共享资源
    rsrcmgr = PDFResourceManager()
    # 创建一个PDF设备对象
    laparams = LAParams()
    device = PDFPageAggregator(rsrcmgr, laparams=laparams)
    # 创建一个PDF解释器对象
    interpreter = PDFPageInterpreter(rsrcmgr, device)

    # 循环遍历列表，每次处理一个page的内容
    for page in doc.get_pages():
        interpreter.process_page(page)                        
        # 接受该页面的LTPage对象
        layout = device.get_result()
        # 这里layout是一个LTPage对象，里面存放着这个 page 解析出的各种对象
        # 包括 LTTextBox, LTFigure, LTImage, LTTextBoxHorizontal 等                            
        for x in layout:
            if isinstance(x, LTTextBoxHorizontal):
                print(x.get_text().strip())
# Out:
# WARNING:pdfminer.layout:Too many boxes (145) to group, skipping.
# 电脑编程技巧与维护
# 1 引言
# Web
# 上的信息量随着互联网的飞速发展以惊人的速度巨
# 增，在这些海量
# 分布
# 动态
# 异质
# 非结构化的资源中，
# 包含了丰富的文本
# 图形图像
# 声音等信息，同时也包含了
# 大量的链接结构信息以及存在于服务器上的用户记录信息
# 面对这些巨量的信息，管理者如何从中查找
# 抽取所需要的
# 数据与有用信息成了一个难题，也正是这个问题促使了单文
# 本
# 单类型的数据挖掘转向了
# 挖掘
# 本文基于这种背景
# 研究分析了
# 数据挖掘的定义
# 分类以及其挖掘技术，并
# 对其挖掘过程中存在的困难与引用进行简单了分析说明
# 、
# 、
# 、
# 、
# 、
# 、
# 。
# 、
# 、
# Web
# 。
# Web
# 、
# 。
# 2 定义与分类
# 2.1 概述
# 数据挖掘是指从大量的
# 不完全的
# 随机的
# 有噪音的
# 实际应用数据中发现隐含的
# 规律性的
# 人们事先未知的但
# 又是存在潜在价值知识的过程
# 数据挖掘是从数据挖掘
# 发展而来，一般是指将数据挖掘技术应用到
# 上
# 具体技
# 术性定义：
# 数据挖掘，简称为
# 挖掘，是一项涉及
# 数据挖掘
# 信息学
# 计算机语言学等多个领域的综合技
# 术
# 挖掘的理论性定义：指从大量
# 文档结构和使用
# 的集合
# 中发现隐含的
# 未知的
# 有潜在应用价值的模式
# 如果将
# 看作输入，
# 看作输出，那么
# 挖掘的过程就是
# 从输入到输出的一个映射
# 挖掘就是从
# 文档
# 活动中抽取出用户感兴
# 趣的
# 潜在有价值模型的隐藏信息
# 挖掘可以在很多方
# 面发挥作用，如对搜索引擎的结构进行挖掘
# 确定权威页面
# 文档分类
# 日志挖掘
# 智能查询
# 建立
# 元数据
# 对远程教育过程信息进行分析等
# 、
# 、
# 、
# 、
# 、
# 。Web
# Web
# 。
# Web
# Web
# WARNING:pdfminer.layout:Too many boxes (112) to group, skipping.
# ...
