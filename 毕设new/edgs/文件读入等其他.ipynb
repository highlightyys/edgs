# %%
import sys
import importlib
importlib.reload(sys)

from pdfminer.pdfparser import PDFParser, PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import PDFPageAggregator
from pdfminer.layout import LTTextBoxHorizontal, LAParams
from pdfminer.pdfinterp import PDFTextExtractionNotAllowed
import os

class PdfToTxt(object):
    
    #从已知文件路径中读取pdf文件，并将其转化为同名txt文件

    def readPDF(path, toPath):
        # 以二进制形式打开pdf文件
        
        with open(path, "rb") as f:
            # 创建一个pdf文档分析器
            parser = PDFParser(f)
            # 创建pdf文档
            pdfFile = PDFDocument()
            # 链接分析器与文档对象
            parser.set_document(pdfFile)
            pdfFile.set_parser(parser)
            # 提供初始化密码
            pdfFile.initialize()
            # 检测文档是否提供txt转换
        if not pdfFile.is_extractable:
            raise PDFTextExtractionNotAllowed
        else:
            # 解析数据
            # 数据管理
            manager = PDFResourceManager()
            # 创建一个PDF设备对象
            laparams = LAParams()
            device = PDFPageAggregator(manager, laparams=laparams)
            # 解释器对象
            interpreter = PDFPageInterpreter(manager, device)
    
            # 开始循环处理，每次处理一页
            for page in pdfFile.get_pages():
                interpreter.process_page(page)
                layout = device.get_result()
                for x in layout:
                    if(isinstance(x, LTTextBoxHorizontal)):
                        with open(toPath, 'a',encoding='utf-8') as f:
                            str = x.get_text()
                            # print(str)
                            f.write(str+"\n")


    def getpdf_list(pdf_path):
        txt_path =  'C:/EdmsData/txt0/'
        #清空txt文件中文件
        shanchu = os.listdir(txt_path)
        print(shanchu)
        for i in range(len(shanchu)):
            os.remove(txt_path+shanchu[i])
        
        all_list = os.listdir(pdf_path)
        path = ''
        
        
        
        txt_list=[]
        for onelist in all_list:
            if onelist.find('pdf') != -1:
                txt_list.append(onelist[0:-4])
                
        print(txt_list)
        for i in range(len(txt_list)):
            path = pdf_path+'/'+txt_list[i]+'.pdf'
            toPath = txt_path+txt_list[i]+'.txt'
            try:
                PdfToTxt.readPDF(path,toPath)
            except:
                continue
            
if __name__ == '__main__':
    pdf_path = 'C:/TMdata/PDF4'
    #将所有pdf转为同名的txt文件
    PdfToTxt.getpdf_list(pdf_path)
# Out:
# ['21世纪的计算机辅助翻译工具_徐彬.txt', '大数据时代的计算机网络安全及防范技术_欧东鑫.txt', '大数据时代计算机网络信息安全问题研究_亓兵.txt']
# ['21世纪的计算机辅助翻译工具_徐彬', '大数据时代的计算机网络安全及防范技术_欧东鑫', '大数据时代计算机网络信息安全问题研究_亓兵']
# WARNING:root:Unknown operator: 'Q\x00'
# WARNING:root:Unknown operator: 'Q\x00'
# WARNING:root:Unknown operator: 'Q\x00'
# WARNING:root:Unknown operator: 'Q\x00'
# WARNING:root:Unknown operator: 'Q\x00'
# WARNING:root:Unknown operator: 'Q\x00'
# WARNING:root:Unknown operator: 'Q\x00'
# WARNING:root:Unknown operator: 'Q\x00'

# %%
#查找文件子目录

def list_all_files(rootdir):
    import os
    _files = []
    list = os.listdir(rootdir) #列出文件夹下所有的目录与文件
    for i in range(0,len(list)):
           path = os.path.join(rootdir,list[i])
           if os.path.isdir(path):
              _files.extend(list_all_files(path))
背景下县级公立医院绩效改革困境_刘丽杭_陶飞旸.txt', 'C:/EdmsData\\txt\\藜麦营养功能与开发利用进展_王启明.txt', 'C:/EdmsData\\txt\\解析装配式建筑工程施工过程中BIM技术的应用_刘志文.txt', 'C:/EdmsData\\txt\\辽宁省特色人才培养模式研究_郭晓林_徐靓.txt', 'C:/EdmsData\\txt\\遗传算法的数据挖掘技术在医疗大数据中的应用研究_陈萌.txt', 'C:/EdmsData\\txt\\面向调度运行分析的电网数据分析与挖掘_张英华.txt', 'C:/EdmsData\\txt\\高校大学生就业指导中的思想政治教育研究_张梦君.txt', 'C:/EdmsData\\txt\\高校油画专业课堂教学改革探究_舒文鑫.txt', 'C:/EdmsData\\w2vmodel.txt']

# %%
# -*- coding: utf-8 -*-
"""
Created on Tue Apr 23 16:17:30 2019

@author: Administrator
"""
#传入文件路径名，将所有pdf转为同名的txt文件保存

import sys
import importlib
importlib.reload(sys)

from pdfminer.pdfparser import PDFParser, PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import PDFPageAggregator
from pdfminer.layout import LTTextBoxHorizontal, LAParams
from pdfminer.pdfinterp import PDFTextExtractionNotAllowed
import os

class PdfToTxt(object):
    
    #从已知文件路径中读取pdf文件，并将其转化为同名txt文件

    def readPDF(path, toPath):
        # 以二进制形式打开pdf文件
   
        with open(path, "rb") as f:
            # 创建一个pdf文档分析器
            parser = PDFParser(f)
            # 创建pdf文档
            pdfFile = PDFDocument()
            # 链接分析器与文档对象
            parser.set_document(pdfFile)
            pdfFile.set_parser(parser)
            # 提供初始化密码
            pdfFile.initialize()
            # 检测文档是否提供txt转换
        if not pdfFile.is_extractable:
            raise PDFTextExtractionNotAllowed
        else:
            # 解析数据
            # 数据管理
            manager = PDFResourceManager()
            # 创建一个PDF设备对象
            laparams = LAParams()
            device = PDFPageAggregator(manager, laparams=laparams)
            # 解释器对象
            interpreter = PDFPageInterpreter(manager, device)
    
            # 开始循环处理，每次处理一页
            for page in pdfFile.get_pages():
                interpreter.process_page(page)
                layout = device.get_result()
                for x in layout:
                    if(isinstance(x, LTTextBoxHorizontal)):
                        with open(toPath, 'a',encoding='utf-8') as f:
                            str = x.get_text()
                            # print(str)
                            f.write(str+"\n")

    
    def list_all_files(rootdir):
        _files = []
        list = os.listdir(rootdir) #列出文件夹下所有的目录与文件
        for i in range(0,len(list)):
            path = os.path.join(rootdir,list[i])
            if os.path.isdir(path):
                _files.extend(PdfToTxt.list_all_files(path))
            if os.path.isfile(path):
                _files.append(list[i])
            print(_files)
        return _files
    
    def getpdf_list(pdf_path):
        txt_path =  'C:/EdmsData/txt0/'
        #清空txt文件中文件
        shanchu = os.listdir(txt_path)
        #print(shanchu)
        for i in range(len(shanchu)):
            os.remove(txt_path+shanchu[i])
        #--------------------------------
        all_list = PdfToTxt.list_all_files(pdf_path)
        print(all_list)
        path = ''
         
        txt_list=[]
        for onelist in all_list:
            if onelist.find('pdf') != -1:
                txt_list.append(onelist[0:-4])
                
        print(txt_list)
        for i in range(len(txt_list)):
            path = pdf_path+'/'+txt_list[i]+'.pdf'
            toPath = txt_path+txt_list[i]+'.txt'
            try:
                PdfToTxt.readPDF(path,toPath)
            except:
                continue
            
            
if __name__ == '__main__':
    pdf_path = 'C:/TMdata/PDF4'
    #将所有pdf转为同名的txt文件
    PdfToTxt.getpdf_list(pdf_path)
# Out:
# ['21世纪的计算机辅助翻译工具_徐彬.pdf']
# ['关于计算机人工智能技术的发展分析与应用探讨_聂华.pdf']
# ['关于计算机人工智能技术的发展分析与应用探讨_聂华.pdf', '计算思维与计算机方法论_董荣胜.pdf']
# ['关于计算机人工智能技术的发展分析与应用探讨_聂华.pdf', '计算思维与计算机方法论_董荣胜.pdf', '计算机网络安全面临的威胁及其防范措施_王麟.pdf']
# ['关于计算机人工智能技术的发展分析与应用探讨_聂华.pdf', '计算思维与计算机方法论_董荣胜.pdf', '计算机网络安全面临的威胁及其防范措施_王麟.pdf', '计算机网络技术在远程监控系统中的应用_吴毅峰.pdf']
# ['21世纪的计算机辅助翻译工具_徐彬.pdf', '关于计算机人工智能技术的发展分析与应用探讨_聂华.pdf', '计算思维与计算机方法论_董荣胜.pdf', '计算机网络安全面临的威胁及其防范措施_王麟.pdf', '计算机网络技术在远程监控系统中的应用_吴毅峰.pdf']
# ['21世纪的计算机辅助翻译工具_徐彬.pdf', '关于计算机人工智能技术的发展分析与应用探讨_聂华.pdf', '计算思维与计算机方法论_董荣胜.pdf', '计算机网络安全面临的威胁及其防范措施_王麟.pdf', '计算机网络技术在远程监控系统中的应用_吴毅峰.pdf', '大数据时代的计算机网络安全及防范技术_欧东鑫.pdf']
# ['21世纪的计算机辅助翻译工具_徐彬.pdf', '关于计算机人工智能技术的发展分析与应用探讨_聂华.pdf', '计算思维与计算机方法论_董荣胜.pdf', '计算机网络安全面临的威胁及其防范措施_王麟.pdf', '计算机网络技术在远程监控系统中的应用_吴毅峰.pdf', '大数据时代的计算机网络安全及防范技术_欧东鑫.pdf', '大数据时代计算机网络信息安全问题研究_亓兵.pdf']
# ['21世纪的计算机辅助翻译工具_徐彬.pdf', '关于计算机人工智能技术的发展分析与应用探讨_聂华.pdf', '计算思维与计算机方法论_董荣胜.pdf', '计算机网络安全面临的威胁及其防范措施_王麟.pdf', '计算机网络技术在远程监控系统中的应用_吴毅峰.pdf', '大数据时代的计算机网络安全及防范技术_欧东鑫.pdf', '大数据时代计算机网络信息安全问题研究_亓兵.pdf']
# ['21世纪的计算机辅助翻译工具_徐彬', '关于计算机人工智能技术的发展分析与应用探讨_聂华', '计算思维与计算机方法论_董荣胜', '计算机网络安全面临的威胁及其防范措施_王麟', '计算机网络技术在远程监控系统中的应用_吴毅峰', '大数据时代的计算机网络安全及防范技术_欧东鑫', '大数据时代计算机网络信息安全问题研究_亓兵']
# WARNING:root:Unknown operator: 'Q\x00'
# WARNING:root:Unknown operator: 'Q\x00'
# WARNING:root:Unknown operator: 'Q\x00'
# WARNING:root:Unknown operator: 'Q\x00'
# WARNING:root:Unknown operator: 'Q\x00'
# WARNING:root:Unknown operator: 'Q\x00'
# WARNING:root:Unknown operator: 'Q\x00'
# WARNING:root:Unknown operator: 'Q\x00'
